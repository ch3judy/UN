# %%
import pandas as pd
import numpy as np

# %%
template = pd.read_excel('sentence_result0421_index.xlsx')

# %%
template.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sector</th>
#       <th>title</th>
#       <th>1.1</th>
#       <th>1.2</th>
#       <th>1.3</th>
#       <th>1.4</th>
#       <th>1.5</th>
#       <th>2.1</th>
#       <th>2.2</th>
#       <th>2.3</th>
#       <th>...</th>
#       <th>16.1</th>
#       <th>16.2</th>
#       <th>16.3</th>
#       <th>16.4</th>
#       <th>16.5</th>
#       <th>16.6</th>
#       <th>16.7</th>
#       <th>16.8</th>
#       <th>16.9</th>
#       <th>16.10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
template.shape
# Out:
# (18, 108)

# %%
template.iloc[:,4:108] = np.NAN

# %%
template.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sector</th>
#       <th>title</th>
#       <th>1.1</th>
#       <th>1.2</th>
#       <th>1.3</th>
#       <th>1.4</th>
#       <th>1.5</th>
#       <th>2.1</th>
#       <th>2.2</th>
#       <th>2.3</th>
#       <th>...</th>
#       <th>16.1</th>
#       <th>16.2</th>
#       <th>16.3</th>
#       <th>16.4</th>
#       <th>16.5</th>
#       <th>16.6</th>
#       <th>16.7</th>
#       <th>16.8</th>
#       <th>16.9</th>
#       <th>16.10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
dict = {'13_45': 'The sector also faces acute shortage of human resources',
 '1_48': 'On the other hand Bhutan continues to face an acute shortage of skilled and highly specialized manpower such as doctors, engineers, ICT experts and teachers',
 '1_70': 'However, our education system continues to be constrained by an acute shortage of teachers and limited capacities',
 '2_32': 'Health Human Resource: The Bhutanese Health System suffers from acute shortage of all categories of health personnel',
 '3_23': 'For instance, in the education sector, where there is already an acute shortage of teachers, the teacher turnover is high at about 4 percent annually',
 '3_33': 'In terms of human resource development, the focus will be on creating skills and knowledge to achieve the objectives of EDP 2010, with an emphasis on addressing the acute shortage of skilled professionals such as doctors, educationists, engineers, architects and ICT specialists',
 '5_5': "The sector's full potential is challenged by low productivity due to issues such as acute shortage of farm labour driven by outbound rural-urban migration, loss of arable land to urbanization, difficult terrain, fragmented land holdings, loss of crops to wildlife, lack of access to market and agricultural credit, climate change and natural disasters, post harvest management issues and subsistence nature of farming"}

# %%
def rename(input):
    for i in range(0,len(input.keys())-1):
        key = str(input.keys()[i]).split('_')[0]
        input[key]=input.pop(input.keys()[i])

# %%
rename(dict)

# %%
dict
# Out:
# {'1': 'On the other hand Bhutan continues to face an acute shortage of skilled and highly specialized manpower such as doctors, engineers, ICT experts and teachers',
#  '13': 'The sector also faces acute shortage of human resources',
#  '1_70': 'However, our education system continues to be constrained by an acute shortage of teachers and limited capacities',
#  '2': 'Health Human Resource: The Bhutanese Health System suffers from acute shortage of all categories of health personnel',
#  '3': 'In terms of human resource development, the focus will be on creating skills and knowledge to achieve the objectives of EDP 2010, with an emphasis on addressing the acute shortage of skilled professionals such as doctors, educationists, engineers, architects and ICT specialists',
#  '3_23': 'For instance, in the education sector, where there is already an acute shortage of teachers, the teacher turnover is high at about 4 percent annually',
# ...

# %%
def match(input):
    for row in range(1,len(template)):
        if str(template['sector'][row]) in input:
            template['1.1'][row] = 'X'

# %%
template.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sector</th>
#       <th>title</th>
#       <th>1.1</th>
#       <th>1.2</th>
#       <th>1.3</th>
#       <th>1.4</th>
#       <th>1.5</th>
#       <th>2.1</th>
#       <th>2.2</th>
#       <th>2.3</th>
#       <th>...</th>
#       <th>16.1</th>
#       <th>16.2</th>
#       <th>16.3</th>
#       <th>16.4</th>
#       <th>16.5</th>
#       <th>16.6</th>
#       <th>16.7</th>
#       <th>16.8</th>
#       <th>16.9</th>
#       <th>16.10</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>...</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
# ...

# %%
match(dict)
# Out:
# C:\Python27\lib\site-packages\ipykernel\__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Python27\lib\site-packages\pandas\core\indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
template.to_excel('sentence_result0420.xlsx')
